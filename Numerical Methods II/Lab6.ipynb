# %% [markdown]
# ![image.png](attachment:efbe5a91-8c13-492a-add3-6335549243d8.png)

# %% [markdown]
# ![зображення.png](attachment:62a44556-bfbc-4cdd-a458-fef885daeb59.png)

# %% [markdown]
# ![зображення.png](attachment:8d9ee477-b309-4e05-b87a-c3ec8d0e4cdd.png)

# %% [markdown]
# ![зображення.png](attachment:9b03bd49-90df-46a8-9d57-991d694ce879.png)

# %% [markdown]
# **Мета роботи**: придбання практичних навичок в чисельному інтегруванні
# звичайних диференційних рівнянь явними і неявними
#
# методами Мілна, Адамса,
# дослідження впливу значення кроку обчислень на точність і збіжність рішення.
# Визначення можливості
#
# застосування
# засобів стандартних
# пакетів для
# отримання результатів.

# %% [markdown]
# ![image.png](attachment:fc146c65-26a1-46be-9e43-380ebaaa8d03.png)

# %% [markdown]
# Варіант № 27

# %% [markdown]
# ![image.png](attachment:efcb8a85-fe1a-46ea-a70b-6499ec04eb46.png)
#
# ![image.png](attachment:f5294dea-b0ca-433c-820e-083af99be4ec.png)

# %% [markdown]
# Введемо нашу задачу Коші та знайдемо її розв’язок за допомогою
# вбудованної функції:
#
# ![image.png](attachment:714c0818-1417-4820-bab8-576d3c73521a.png)
#
# Будуємо графік:
#
# ![image.png](attachment:267e9e7e-990a-4b0b-b485-ef36dd633a9c.png)

# %% [markdown]
# (за умовою $t_k$ = 3, тому будемо порівнювати розв'язки на відрізу [$t_0$; $t_k$] = [1; 3])

# %% [markdown]
# Будемо знаходити розв’язок задачі Коші за допомогою багатокрокового метода Мілнера за схемою предиктор-коректор. Метод Мілнера має четвертий порядок точності. Нехай похибка обчислень 𝜏 = 0.1. Для запуску цього методу нам треба підготувати 4 опорні точки. Оберемо стартові значення з удосконаленого методу Ейлера:
#
# ![image.png](attachment:39bcf8c4-6b6e-4a28-b7a8-73b2e97ac863.png)
#
# Отже ми отримали 4 опорні точки

# %% [markdown]
# Знайдемо чисельне розв’язання нашої задачі Коші за допомогою
# багатокрокового методу Мілна:
#
# Запишемо функцію f(права частина нашого диф. рівняння), початкові
# умови, похибку h, задамо m-кількість кроків.
#
# Знайдені значення задачі в
# точках 1, 1.2, 1.4, 1.6 запишемо в u[0], u[1], u[2], u[3] відповідно:
#
# ![image.png](attachment:b3a393ad-069d-4e0b-8f6e-45258b4e0070.png)
#
# ![image.png](attachment:6aab6d19-666b-40b8-a30e-bc99b423a013.png)

# %% [markdown]
# ![image.png](attachment:3e1c0522-e182-40ae-8f85-a2782d66f129.png)
#
# Для прикладу знайдемо прогноз та корецію Мілна для п’ятої точки:
#
# ![image.png](attachment:d098944f-3e50-4ef1-a956-4e79ba1717fd.png)
#
# Бачимо, що вони є схожими (задовільняють задану похибку)

# %% [markdown]
# Реалізуємо метод Мілна:
#
# ![image.png](attachment:458db8e6-c0f5-44af-b1ac-d54242d68f86.png)
#
# ![image.png](attachment:9db7241f-8621-43a6-88ab-d47032352509.png)
#
# Подамо розв’язок у вигляді таблиці:
#
# ![image.png](attachment:a72a8dc4-caf2-4d0e-b588-bc7e785180ae.png)
#
# ![image.png](attachment:9960dc7f-764a-488d-a482-b57c03bf6242.png)

# %% [markdown]
# Побудуємо інтерполяційний багаточлен по знайденим точкам:
#
# ![image.png](attachment:2c467bdb-d98a-47bd-91ca-d58860bb617f.png)
#
# Побудуємо графік:
#
# ![image.png](attachment:9b0b16e8-928a-42d3-b069-214ba0efdfc6.png)
#
# По малюнку бачимо, що графіки майже повністю співпадають

# %% [markdown]
# Розв’яжемо чисельно нашу задачу Коші за допомогою багатокрокових методів Адамса-Башфорта, Адамса-Моултона.
#
# 4 опорні точки беремо ті самі (знайдені за допомогою удосконаленого
# методу Ейлера). Ці точки зберігаються в масиві ww
#
# ![image.png](attachment:c8e2debe-b0d8-4430-b3ec-ff7488f8b270.png)
#
# Числове розв’язання рівняння, отримане методами
# Адамса-Башфорта, Адамса-Моултона:
#
# ![image.png](attachment:fc441b19-bac5-41f1-aceb-00e48372a29a.png)
#
# Отримаємо:
#
# ![image.png](attachment:030cd524-3b8a-42f4-b5c9-e94f4940c008.png)
#
# Створимо по цим точкам інтерполяційний багаточлен та побудуємо його
# графік:
#
# ![image.png](attachment:1d3bb1ab-1ff8-4cd2-9597-8c065c5ccd8f.png)
#
# Графічно порівняємо цей розв’язок (пунктиром) з еталонним:
#
# ![image.png](attachment:aed52092-bfdd-4dab-be71-615ab8e8e251.png)
#
# Графіки майже співпали.
#
# ![image.png](attachment:a377517a-dc63-45b0-95dd-e48778659ebe.png)

# %% [markdown]
# Порівняємо знайдені розв’язки з тими, що ми знайшли у КП5 за
# допомогою метода типу Рунге – Кутти 4 порядку:
# Розв’язок там був такий:
#
# ![image.png](attachment:3d15e49c-948a-4a5d-b540-d191e6cdeaa7.png)
#
# Побудуємо графік цього розв’язку (червоний графік) та розв’язку, знайденого за допомогою
# багатокрокових методів Адамса-Башфорта, Адамса-Моултона (оранжевий пунктир):
#
#
#
# ![image.png](attachment:8a1ed847-c9aa-4dde-8bdd-a5d38f40b224.png)
#
# Бачимо, що графічно розв’язок майже співпав. Проте мала похибка все є
# таки існує (також, можемо побачити, що інтерполяційні багаточлени дуже
# відрізняються один від одного).

# %% [markdown]
# **Висновок**:
# Під час виконання цієї практичної роботи, було реалізовано багатокрокові
# методи розв’язання завдання Коші для звичайних
#
# диференційних рівнянь.
# Було побудовано метод Мілана та Адамса, а також проаналізовано ці два
# методи та порівняно їх з однокроковими
#
# методами
# розв’язання таких
# типів задач. В результаті було виявлено, що метод Мілана спрацював
# краще за метод Адамса. А однокрокові
#
# методи
# розв’язання завдання Коші
# для звичайних диференційних рівнянь є кращими та більш точними за
# багатокрокові методи.
