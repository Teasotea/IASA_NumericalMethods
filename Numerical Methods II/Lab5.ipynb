# %% [markdown]
# ![image.png](attachment:711a86d2-ad9a-4076-8e3e-adeba8925eaa.png)

# %% [markdown]
# ![зображення.png](attachment:62a44556-bfbc-4cdd-a458-fef885daeb59.png)

# %% [markdown]
# ![зображення.png](attachment:8d9ee477-b309-4e05-b87a-c3ec8d0e4cdd.png)

# %% [markdown]
# ![зображення.png](attachment:9b03bd49-90df-46a8-9d57-991d694ce879.png)

# %% [markdown]
# **Мета роботи**: придбання практичних навичок в чисельному інтегруванні
# звичайних диференційних рівнянь явними і неявними методами
#
# типу Рунге-
# Кутти, дослідження впливу значення кроку обчислень на точність і збіжність
# розв’язання. Визначення можливості застосування
#
# засобів стандартних пакетів
# для отримання результатів.

# %% [markdown]
# ![image.png](attachment:6a967297-b7d4-41f2-8a92-6b823128c235.png)

# %% [markdown]
# Варіант № 27

# %% [markdown]
# ![image.png](attachment:efcb8a85-fe1a-46ea-a70b-6499ec04eb46.png)
#
# ![image.png](attachment:f5294dea-b0ca-433c-820e-083af99be4ec.png)

# %% [markdown]
# ### Знайдемо аналітичний розв’язок (якщо він існує):
# $y'=y \cdot \frac{ln(t)}{t}$,
# $t(1) = 1$,
# $t_k=3$
#
# $y=C \cdot e^{\frac{ln^2(t)}{2}}$
#
# Знайдемо коефіцієнт С:

# %% [markdown]
# $y(1)= C =1 $
#
# Отже, отримали аналітичний розв’язок задачі Коші:
#
# $y=e^{\frac{ln^2(t)}{2}}$

# %% [markdown]
# Спробуємо знайти розв'язок з допомогою вбудованої функції:
#
# ![image.png](attachment:af01b320-352e-4baa-8005-1ce5f36144c3.png)
#
# Бачимо, що розв'язок співпав.
# Надалі, запам’ятаємо цей розв’язок, як еталонний

# %% [markdown]
# Будуємо графік:
#
# ![image.png](attachment:6090f29c-dd89-434b-adfc-4cadc9678c0f.png)

# %% [markdown]
# **Метод Ейлера**
#
# Спробуємо знайти розв’язок за допомогою метода Ейлера.
# Знайдемо розв’язання для 10-ти точок в діапозоні від 0.1 (почнемо з 0.1, щоб уникнути ділення на нуль) до 3.1, та з кроком τ=0.3:
# (f-значення похідної від y, w- масив, де зберігаємо значення t(1) та y(2))
#
# ![image.png](attachment:c7bafe2c-0ab4-463f-8430-3ec9aeddc9f8.png)
#
# Отримали 10 точок та значення в них. Аби побудувати графік-створимо інтерполяційний многочлен:
#
# ![image.png](attachment:e90e07e2-1871-441f-a9c5-f76bdff990b9.png)
#
# Графік розв’язання цього дифрівняння за допомогою методу Ейлера на [0.1,4] зображений пунктиром. Порівняємо цей графік с еталонним:
#
# ![image.png](attachment:144fc8a8-b810-4be7-a5cf-98a3fd3cddde.png)
#
# Бачимо, що похибка є досить великою.

# %% [markdown]
# **Неявний метод Рунге – Кутти**
#
# Розв’яжемо це диф. рівняння за допомогою неявного метода типу Рунге – Кутти третього порядку.
#
# Вводимо початкові умови, кількість кроків(m), крок  τ, записуємо у масив S (де будуть зберігатися t та y(t)) значення t0 та y0, ітераційний процес
#
# ![image.png](attachment:36827d92-5059-4ea1-86be-04de48b61002.png)
#
# ![image.png](attachment:e41a2e91-309d-492e-a9a7-abfd1e7fc171.png)
#
# Розподілимо ці точки по парам (t, y(t)) та побудуємо інтерполяційний многочлен:
#
# ![image.png](attachment:3d224867-2a7e-46bb-a3ed-fe7277128a3d.png)

# %% [markdown]
# Будуємо графік:
#
# ![image.png](attachment:0e19e7d2-7619-4cc3-9dee-00920c19f82d.png)

# %% [markdown]
# Розв’яжемо це диф. рівняння за допомогою неявного метода типу Рунге – Кутти четвертого порядку:
#
# ![image.png](attachment:81790cbd-8586-4d6a-b3e2-51639be730b1.png)
#
# Вводимо початкові умови, кількість кроків(m), крок  τ, записуємо у масив U (де будуть зберігатися t та y(t)) значення t0 та y0
#
# Ітераціний процес
#
# ![image.png](attachment:4be28edb-484a-49db-8322-155bba2495a6.png)
#
# Отримаємо:
#
# ![image.png](attachment:73d26a0b-4b78-40a8-bcc6-84d3dba240a6.png)
#
# Розбиваємо на пари (t, y(t)), створюємо інтерполяційний многочлен:
#
# ![image.png](attachment:ed32ca65-f2ca-4141-a26a-bd9fcedb7633.png)
#
# ![image.png](attachment:e7ced86e-adcd-4fea-a766-bb69141ad74a.png)
#
# Будуємо графік для цього многочлена:
#
# ![image.png](attachment:7adf626d-a349-4a2d-bdc2-25173db02e37.png)
#
# Спробуємо графічно порівняти розв’язання методами типу Рунге – Кутти 3 та 4 порядків:
#
# ![image.png](attachment:596cb101-f4cd-4bdb-afc4-d5aec3f5b3f5.png)
#
# Бачимо, що похибка настільки мала, що графічно її не видно (на вигляд графіки співпали).
# Проте інтераційні многочлени не однакові.

# %% [markdown]
# Спробуємо намалювати в одній осі графіки порівняти розв’язання методами типу Рунге – Кутти 3 та 4 порядків, методом Ейлера та еталонний графік:
#
# ![image.png](attachment:a26aee4b-fd7f-4409-bb3a-2e1166098aa5.png)

# %% [markdown]
# Бачимо, що з розв’язком даного рівняння найкраще впорався
# явний метод Рунге-Кутти 4 порядку (червоний пунктир). Найгіршим виявився метод Ейлера (графік синім пунктиром), оскільки
# можемо помітити значну похибку.

# %% [markdown]
# **Висновок**:
# Під час виконання цієї практичної роботи, було реалізовано
# методи розв’язання задачі Коші, а саме: неявний метод Рунге-Кутти
# різних порядків та метод Ейлера. Було проаналізовано та порівняно отримані значення та побудовано
# графічне зображення отриманих значень для кожного методу.
