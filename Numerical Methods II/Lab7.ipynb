# %% [markdown]
# <div align="center">
# МІНІСТЕРСТВО ОСВІТИ І НАУКИ УКРАЇНИ<br>
# ІНСТИТУТ ПРИКЛАДНОГО СИСТЕМНОГО АНАЛІЗУ<br>
# НАЦІОНАЛЬНОГО ТЕХНІЧНОГО УНІВЕРСИТЕТУ УКРАЇНИ<br>
# «КИЇВСЬКИЙ ПОЛІТЕХНІЧНИЙ ІНСТИТУТ»<br>
# КАФЕДРА МАТЕМАТИЧНИХ МЕТОДІВ СИСТЕМНОГО АНАЛІЗУ<br>
# </div>
# <br><br><br><br><br><br><br><br>
# <div align="center"><strong>Лабораторна робота №7</strong></div>
# <div align="center">З курсу "Чисельні методи"</div>
# <div align="center">Тема "ЧИСЕЛЬНІ МЕТОДИ РОЗВ’ЯЗАННЯ РІВНЯНЬ З ЧАСТИННИМИ ПОХІДНИМИ.</div>
# <div align="center">ЕЛІПТИЧНІ КРАЙОВІ ЗАВДАННЯ"</div>
# <br><br><br><br>
# <div align="right">
#     <strong>Виконала:</strong><br>
#     Студентка групи КА-02<br>
#     Шапошнікова С. В.<br><br>
#     <strong>Прийняла:</strong><br>
#     Дмитрієва О. А.
# </div>
# <br><br><br><br><br><br><br>
# <div align="center">Київ - 2022</div>
#
#
# <hr>

# %% [markdown]
# **Мета роботи**: надбання практичних навичок в моделюванні систем,
# що описуються рівняннями із частинними похідними еліптичного типу.
#
# Застосування на практиці мету сіток, апроксимації граничних умов і вибір
# ітераційного методу розв’язання з урахуванням умов точності і збіжності,
#
# що висуваються до поставленого завдання.

# %% [markdown]
# ![image.png](attachment:a3f05fea-53b9-4d82-9706-6254a77168c0.png)
#
# ![image.png](attachment:850ea949-b969-4182-838e-114e520b651b.png)

# %% [markdown]
# Варіант № 27

# %% [markdown]
# ![image.png](attachment:91b47a62-bd47-42a2-ac84-6d6b744dbea6.png)
#
# ![image.png](attachment:064fda68-b833-41f9-8a35-90ae6ac6a51d.png)

# %% [markdown]
# ![image.png](attachment:535cd9b1-a08c-4050-a6d5-9d841f1af9b0.png)
#
# ![image.png](attachment:344dfac1-d8a1-44ac-be30-7b98e372e8cb.png)
#
# ![image.png](attachment:b0324326-d53b-4151-804e-1cdc75703b22.png)

# %% [markdown]
# ![image.png](attachment:c56f9698-48a5-4cfe-9eca-e90afb7b9198.png)

# %% [markdown]
# Бачимо, що змінна x бігає від 0 до 2, а змінна y – від 1 до 2
# Візьмемо m=21, тоді h=1/(n-1)=1/(21-1)=0.1
# Якщо зробимо заміни:
#  x=ih
#  y=jh
# то i має бігати з 0 до m-1 (0;20), а проміжок для j має бути вдвічі менший - (0;10), тоді беремо для j проміжок (0;n-1), де n=11.
#
# Тепер запишемо граничні умови, зробимо заміни x та y, помножимо f на h^2, аби застосувати потім метод сіток, а також візьмемо за початкову точку сітки точку (0;1), тому замінюємо в граничних умовах x на ih, а y на jh+1:
#
# i буде бігати з (0;20), тоді i*h=i*0.1 буде бігати з 0 до 2, а тоді ih буде бігати з 0 до 2 (як і треба за умовою)
#
# j буде бігати з (0;10), тоді j*h=j*0.1 буде бігати з 0 до 1, а тоді jh+1 буде бігати з 1 до 2 (як і треба за умовою)
#
# Тепер запишемо це все у Mathematica:
# Вводимо початкові(оговорені вище) умови та ініціалізацію правих частин системи, граничних умов і допоміжних масивів:
#
# ![image.png](attachment:0076d60a-f1f2-4594-b284-aaa0bc19a858.png)

# %% [markdown]
# Заповнюємо праву частину та початкову ініціалізацію (маисив u-нулями)
#
# ![image.png](attachment:21863f70-7314-4ad0-88b0-80c53becc6c2.png)

# %% [markdown]
# Вводимо в масив u граничні умови (оговорено вище):
#
# ![image.png](attachment:cd392663-7e57-4b3f-b9e1-fb1bf73c01a6.png)
#
# Виводимо нашу прямокутну сітку:
#
# ![image.png](attachment:bfc9bb68-1a85-4c1b-a6f4-cf092a3fa845.png)

# %% [markdown]
# Тепер застосуємо метод верхньої релаксації:
#
# ![image.png](attachment:3c74cce6-9052-4a77-9be9-71d3fcc4c58e.png)
#
# Виводимо нашу прямокутну сітку:
#
# ![image.png](attachment:5babf280-1e29-4b74-90da-ab10b126a99b.png)

# %% [markdown]
# Графік 3D:
#
# ![image.png](attachment:140ebacc-f321-489c-9faf-224e75600bf3.png)

# %% [markdown]
# Кількість ітерацій методу верхньої релаксації (k) та реальне значення похибки:
#
# ![image.png](attachment:0693e3fc-e955-4f41-b4f1-96667845ed03.png)

# %% [markdown]
# **Висновок**:
#
# Було пропрацьовано моделювання систем, що описуються рівняннями із частинними похідними еліптичного типу.
#
# Застосувано метод сіток, апроксимацію граничних умов і вибрано ітераційний метод розв’язання з урахуванням умов
#
# точності і збіжності,
# що висуваються до поставленого завдання.
