# %% [markdown]
# <div align="center">
# МІНІСТЕРСТВО ОСВІТИ І НАУКИ УКРАЇНИ<br>
# ІНСТИТУТ ПРИКЛАДНОГО СИСТЕМНОГО АНАЛІЗУ<br>
# НАЦІОНАЛЬНОГО ТЕХНІЧНОГО УНІВЕРСИТЕТУ УКРАЇНИ<br>
# «КИЇВСЬКИЙ ПОЛІТЕХНІЧНИЙ ІНСТИТУТ»<br>
# КАФЕДРА МАТЕМАТИЧНИХ МЕТОДІВ СИСТЕМНОГО АНАЛІЗУ<br>
# </div>
# <br><br><br><br><br><br><br><br>
# <div align="center"><strong>Лабораторна робота №8</strong></div>
# <div align="center">З курсу "Чисельні методи"</div>
# <div align="center">Тема "ЧИСЕЛЬНІ МЕТОДИ РОЗВ’ЯЗАННЯ РІВНЯНЬ З ЧАСТИННИМИ ПОХІДНИМИ.</div>
# <div align="center">ПАРАБОЛІЧНІ КРАЙОВІ ЗАВДАННЯ"</div>
# <br><br><br><br>
# <div align="right">
#     <strong>Виконала:</strong><br>
#     Студентка групи КА-02<br>
#     Шапошнікова С. В.<br><br>
#     <strong>Прийняла:</strong><br>
#     Дмитрієва О. А.
# </div>
# <br><br><br><br><br><br><br>
# <div align="center">Київ - 2022</div>
#
#
# <hr>

# %% [markdown]
# **Мета роботи**: надбання практичних навичок в моделюванні
# динамічних систем управління, що описуються рівняннями із частинними
# похідними
#
# параболічного типу.
# Застосування на практиці мету сіток,
# апроксимації граничних і початкових умов, вибір різницевої схеми з
# урахуванням умов
#
# точності і збіжності,
# що висуваються до поставленої
# задачі. Побудова різницевих схем підвищеної точності. Визначення
# різницевих схем розщеплення.

# %% [markdown]
# ![image.png](attachment:1a921251-755b-40cb-bfc5-74bbc8e4b715.png)
#
# ![image.png](attachment:661c496a-7401-40e5-bf96-e4bf7b41f4e9.png)

# %% [markdown]
# ![image.png](attachment:2752bd6c-b8ff-4767-b112-36e3c5843621.png)

# %% [markdown]
# Варіант № 27

# %% [markdown]
# ![image.png](attachment:85a2f00c-9563-4c3d-8088-4c1e254a971e.png)
#
# ![image.png](attachment:fdce7808-1e04-4cb5-a6b6-6e8c89a484ee.png)

# %% [markdown]
# $  \frac{\partial{u}}{\partial{t}} =  1.5 \frac{\partial^2{u}}{\partial{x^2}} $
#
# 0 < x < 1 = l
#
# 0 < t < T, Т – час настання сталого режиму (ε ≤ 0.01)
#
# 𝑢(𝑥, 0) = 𝑓(𝑥) = 12 $\sqrt{x}$ + 3
#
# 𝑢(0, 𝑡) = 11
#
# 𝑢(1, 𝑡) = 𝑢(𝑙, 𝑡) = 1
#
# a = $ \sqrt{1.5} $

# %% [markdown]
# Побудуємо явну різницеву схему:
#
# ![image.png](attachment:396c6fb6-fc0d-42be-b75f-3a61871845fe.png)
#
# ![image.png](attachment:dd54d95d-0954-4239-b754-e93f6761e6e1.png)
#
# ![image.png](attachment:2a6ab511-c497-429b-b34f-ec21e3fbf974.png)

# %% [markdown]
# ![image.png](attachment:cc8bd5ff-32fc-456e-8ae1-3ab0ddfded83.png)
#
# Побудуємо отримані графіки та їх об’єднання за просторовими шарами:
#
# ![image.png](attachment:e6d434b6-f847-4159-8e37-4ea126a2d4d6.png)
#
# ![image.png](attachment:61c95e48-873a-4f69-acae-1b9b18c961ca.png)
#
# ![image.png](attachment:ed4780ca-40bd-427a-97b1-e5ffb5c832a7.png)
#
# 3D модель:
#
# ![image.png](attachment:4ebe90ca-4ade-4ea1-b35b-c7ed91de972b.png)

# %% [markdown]
# Складемо програму розв’язання задачі за неявною п’ятиточковою тришаровою схемою та отримаємо розв’язок:
#
# Трохи змінимо формулу, аби виразити ![image.png](attachment:14aae04c-c1d1-49d8-9faf-c086ecf1a323.png)
#
# ![image.png](attachment:dfeb9cb2-e43b-4e5b-9255-78b0c632c1e8.png)
#
# Тепер використовуємо отриману фомулу задля знахождення результату:
#
# ![image.png](attachment:b52af196-b298-407f-a6c4-e7109916bfaf.png)
#
# ![image.png](attachment:74c849d4-b161-4a8d-9d82-afc3eff4cfe5.png)

# %% [markdown]
# **Висновок**: Під час виконання лабораторної роботи, було змодельовано
# динамічні системи управління, що описуються рівняннями із частинними
# похідними параболічного типу. Застосувано на практиці метод сіток,
# апроксимацію граничних і початкових умов, вибір різницевої схеми з
# урахуванням умов точності і збіжності, що висуваються до поставленої
# задачі. Побудовано різницеві схеми підвищеної точності. Визначено
# різницеві схеми розщеплення. Таким чином, були реалізовані і досліджені явна різницева схема та п’ятиточкова тришарова
# неявна різницева схема. Побудовано графік розв’язку функції
# u(t,x).
