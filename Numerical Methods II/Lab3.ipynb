# %% [markdown]
# ![image.png](attachment:6ed10e35-2287-43a8-ad67-a7a0a28ae7d3.png)

# %% [markdown]
# ![зображення.png](attachment:62a44556-bfbc-4cdd-a458-fef885daeb59.png)

# %% [markdown]
# ![зображення.png](attachment:8d9ee477-b309-4e05-b87a-c3ec8d0e4cdd.png)

# %% [markdown]
# ![зображення.png](attachment:9b03bd49-90df-46a8-9d57-991d694ce879.png)

# %% [markdown]
# **Мета роботи**: придбання практичних навичок в чисельному визначенні
# власних значень і власних векторів матриць на підставі використання
#
# характеристичних рівнянь і ортогональних перетворень. Визначення
# можливості застосування засобів стандартних пакетів для отримання
# результатів.

# %% [markdown]
# ![image.png](attachment:0ff227dc-938f-45ea-82c7-f55ba2281d67.png)

# %% [markdown]
# Варіант № 27

# %% [markdown]
# ![image.png](attachment:bd6e0cb7-987a-4706-b878-873b20ab825b.png)

# %% [markdown]
# # 1-2

# %% [markdown]
# Для знаходження власних чисел матриці будемо використовувати
# метод Фаддєєва–Левер’є

# %% [markdown]
# ![image.png](attachment:df909480-cf37-4717-bf08-ff8c20575836.png)
#
# ![image.png](attachment:5c1bb491-d9f6-4c5d-b872-836fe1e6fd13.png)

# %% [markdown]
# ![image.png](attachment:28f399c7-f44c-4a65-ae0c-005325bc6bce.png)

# %% [markdown]
# Генеруємо задану матрицю:

# %% [markdown]
# ![image.png](attachment:94fd23b2-b5c2-44cb-9b7f-256d0f8bb63d.png)

# %% [markdown]
# Використовуємо метод Фаддєєва–Левер’є для побудови
# характеристичного рівняння:

# %% [markdown]
# ![image.png](attachment:64ea0b97-1d33-4462-99f1-bd9aadfee244.png)

# %% [markdown]
# ![image.png](attachment:6b16a7e0-3937-4569-98d2-48afed7456c7.png)

# %% [markdown]
# Отримали:

# %% [markdown]
# ![image.png](attachment:5e288e3b-31ba-4a8c-aca8-99b3905089bb.png)

# %% [markdown]
# Зробимо перевірку:
#
# 𝑀𝑎𝑡𝑟𝑖𝑥𝐹𝑜𝑟𝑚[𝐴. 𝐾[1] + 𝑏[1] ∗ 𝐼𝑑𝑒𝑛𝑡𝑖𝑡𝑦𝑀𝑎𝑡𝑟𝑖𝑥[𝑛]]

# %% [markdown]
# ![image.png](attachment:5677f746-4177-4ef7-86bd-c9ddde53b45e.png)

# %% [markdown]
# Отже можемо тепер побудувати наше характеристичне рівняння:
#
# ![image.png](attachment:0e739fa6-aa72-4bdc-bbdb-97700a5bd974.png)

# %% [markdown]
# Отже бачимо, що 2 з 6 коренів є дійсними.

# %% [markdown]
# Побудуємо декілька графіків на різних
# відрізках ОХ:
#
# ![image.png](attachment:c8a62b70-9a3f-46b4-9571-edb54d51b748.png)
#
# ![image.png](attachment:8eae0d47-d854-436c-aaf7-22d00f5de81a.png)
#
# ![image.png](attachment:1f8b7d5d-b677-419c-84af-1fa376c053af.png)

# %% [markdown]
# Знайдемо дійсні корені за допомогою метода Ньютона

# %% [markdown]
# ![image.png](attachment:a3b3e53e-86dc-4563-a978-0bc1ecafb800.png)

# %% [markdown]
# f-рівняння характеристики
#
# f1-похідна першого порядку від цього рівняння
#
# f2-похідна другого порядку
#
# Перший корінь належить інтервалу по Х від -1 до 0.
#
# Знайдемо його з точністю 0.001 (за допомогою метода Ньютона):
#
# ![image.png](attachment:3d30a1c1-ff65-4fbe-8ad6-3d975fcd1ff9.png)

# %% [markdown]
# Другий корінь належить інтервалу по Х від 2 до 4.
# Знайдемо його з точністю 0.001 (за допомогою метода Ньютона):
#
# ![image.png](attachment:25534369-4c00-4865-97ee-cc2ca9f24789.png)

# %% [markdown]
# Отже дійсні власні числа матриці мають вигляд:
#
# -0.27521
#
# 2.7852

# %% [markdown]
# Для знахождення комплексних власних чисел будемо використовувати
# метод Мюллера.
# Використаємо вбудовану функцію Eigenvalues, аби знайти власні числа та
# дізнатися якому проміжку належать ті з них, які є комплексними.
# Беремо проміжок від 5 до 8.5:
#
# ![image.png](attachment:09e6dd19-26a1-43f3-bb9d-2627a44e57db.png)

# %% [markdown]
# Отримаємо чотири комплексних власних числа:
#
# $-0.484505 \pm 4.30817i$
#
# $7.72951 \pm 1.95865i$

# %% [markdown]
# За допомогою вбудованої функції Eigenvalues отримаємо такі власні числа:
#
# ![image.png](attachment:a9e460dd-f2b9-4d4b-adba-114b0b1d98c5.png)

# %% [markdown]
# Скоріш за все, програма їх округлила.
# Порівняємо з нашими власними числами:
#
# $-0.27521$
#
# $2.7852$
#
# $-0.484505 \pm 4.30817i$
#
# $7.72951 \pm 1.95865i$
#
# Бачимо, що власні числа майже співпали

# %% [markdown]
# # 3 - 4

# %% [markdown]
# ![image.png](attachment:556b188b-9f73-4b53-9d5f-664ca3c24544.png)
#
# ![image.png](attachment:06a4e250-347e-4d97-b160-fe48db8ca87a.png)

# %% [markdown]
# Бачимо, що на головній діагоналі числа майже однакові порівняно зі
# знайденими дійсними власними числами
#
# ![image.png](attachment:d0da7c8f-354a-4d18-a879-d04800214fed.png)

# %% [markdown]
# Задля знахождення значень з точністю 0.01 знадобиться 4 ітерації (=n^2):
#
# ![image.png](attachment:61008ec5-b2d0-49b2-bd8f-4a4f16c56032.png)

# %% [markdown]
# **Висновок**: Отримано практичні навички в чисельному визначенні
# власних значень матриць на підставі використання характеристичних
# рівнянь
#
# і ортогональних перетворень. Застосовано засоби
# стандартних пакетів для отримання результатів.
